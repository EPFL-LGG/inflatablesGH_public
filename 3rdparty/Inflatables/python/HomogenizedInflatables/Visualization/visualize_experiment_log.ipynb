# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
with open('../experiments/parallelized_experiments/output/mirror_cosine_dash/2023_10_25_14_54/experiment_result.json', 'r') as fp:
    curr_json = json.load(fp)

# %%
df = pd.DataFrame(curr_json['data'])

# %%
df.hist('Stiffness solved using shift'), df.hist('Simulation Kappa value'), df.count(), df.sum()
