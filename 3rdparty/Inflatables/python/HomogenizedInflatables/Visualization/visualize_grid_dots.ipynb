# %%
import matplotlib.pyplot as plt
import numpy as np
import visualize_stiffness

# %% [markdown]
# ### Two dash shift

# %% [markdown]
# ### Kappa

# %%
name = "grid_dots"

# %%
data = []

for i in range(50):
    data.append(np.load("../experiments/output/grid_dots/2023_04_26_19_20/kappa_grid_dots_{}.npy".format(i), allow_pickle = True))

# %%
visualize_stiffness.plot_kappa(data, name)

# %%
np.load("../experiments/output/three_star/2023_04_26_19_43/high_pressure_dofs_three_star_1.0_0.00.npy")
