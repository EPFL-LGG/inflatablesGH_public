# %%
import numpy as np

# %%
experiment_file = '../experiments/output/tessellation_zigzag_line_10_to_90/2023_12_08_12_01/experiment_result.json'

# %% [markdown]
# ## Overview

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
with open(experiment_file, 'r') as fp:
    data = json.load(fp)

# %%
df = pd.DataFrame(data['data'])
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 5))
a = (df.hist('Ipu simulation succeed', ax = axes[0]), df.hist('Planar equilibrium', ax = axes[1]), df.hist('Simulation Kappa value', ax = axes[2]))

# %%
import visualize_stiffness
import importlib
importlib.reload(visualize_stiffness)

# %%
valid_tags = np.array(df['name'][df['Planar equilibrium'] == 1])

# %%
valid_tags

# %%
kappa_path = None
stiffness_path = '../experiments/output/tessellation_zigzag_line_10_to_90/2023_12_08_12_01/'

# %%
name = 'tessellation_zigzag_line_10_to_90'

# %%
bending_stiffness_data, stretching_stiffness_data, scale_factor_data, used_tags = visualize_stiffness.plot_all_data(kappa_path, stiffness_path, name, valid_tags)
